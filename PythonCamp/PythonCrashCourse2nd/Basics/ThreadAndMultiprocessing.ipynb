# %% [markdown]
# ### 线程

# %% [markdown]
# #### 线程池

# %% [markdown]
# ##### 线程池的使用
# * 调用 ThreadPoolExecutor 类的构造器创建一个线程池
# * 定义一个普通函数作为线程任务
# * 调用 ThreadPoolExecutor 对象的 submit() 方法来提交线程任务
# * 调用 ThreadPoolExecutor 对象的 shutdown() 方法来关闭线程池

# %%
from concurrent.futures import ThreadPoolExecutor
import threading
import time


# 定义一个准备作为线程任务的函数
def action(max):
    t_sum = 0
    for i in range(max):
        print(threading.current_thread().name + ' ' + str(i))
        t_sum += i
    return t_sum


# 创建一个包含 2 条线程的线程池
pool = ThreadPoolExecutor(max_workers=2)
# 向线程池提交一个 task、action 的参数为 50
future_1 = pool.submit(action, 50)
# 向线程池再提交一个 task、action 的参数为 100
future_2 = pool.submit(action, 100)
# 判断 future_1 代表的任务是否结束
print(future_1.done())
time.sleep(3)
# 判断 future_2 代表的任务是否结束
print(future_2.done())
# 查看 future_1 代表的任务返回的结果
print(future_1.result())
# 查看 future_2 代表的任务返回的结果
print(future_2.result())
# 关闭线程池
pool.shutdown()
# Out:
# ThreadPoolExecutor-2_0 0
# ThreadPoolExecutor-2_0 1
# ThreadPoolExecutor-2_0 2
# ThreadPoolExecutor-2_0 3
# ThreadPoolExecutor-2_0 4
# ThreadPoolExecutor-2_0 5
# ThreadPoolExecutor-2_0 6
# ThreadPoolExecutor-2_0 7
# ThreadPoolExecutor-2_0 8
# ThreadPoolExecutor-2_0 9
# ThreadPoolExecutor-2_0 10
# ThreadPoolExecutor-2_0 11
# ThreadPoolExecutor-2_0 12
# ThreadPoolExecutor-2_0 13
# ThreadPoolExecutor-2_0 14
# ThreadPoolExecutor-2_0 15
# ThreadPoolExecutor-2_0 16
# ThreadPoolExecutor-2_0 17
# ThreadPoolExecutor-2_0 18
# ThreadPoolExecutor-2_0 19
# ThreadPoolExecutor-2_0 20
# ThreadPoolExecutor-2_0 21
# ThreadPoolExecutor-2_0 22
# ThreadPoolExecutor-2_0 23
# ThreadPoolExecutor-2_0 24
# ThreadPoolExecutor-2_0 25
# ThreadPoolExecutor-2_0 26
# ThreadPoolExecutor-2_0 27
# ThreadPoolExecutor-2_0 28
# ThreadPoolExecutor-2_0 29
# ThreadPoolExecutor-2_0 30
# ThreadPoolExecutor-2_0 31
# ThreadPoolExecutor-2_0 32
# ThreadPoolExecutor-2_0 33
# ThreadPoolExecutor-2_0 34
# ThreadPoolExecutor-2_0 35
# ThreadPoolExecutor-2_0 36
# ThreadPoolExecutor-2_0 37
# ThreadPoolExecutor-2_0 38
# ThreadPoolExecutor-2_0 39
# ThreadPoolExecutor-2_0 40
# ThreadPoolExecutor-2_0 41
# ThreadPoolExecutor-2_0 42
# ThreadPoolExecutor-2_0 43
# ThreadPoolExecutor-2_0 44
# ThreadPoolExecutor-2_0 45
# ThreadPoolExecutor-2_0 46
# ThreadPoolExecutor-2_0 47
# ThreadPoolExecutor-2_0 48
# ThreadPoolExecutor-2_0 49
# True
# ThreadPoolExecutor-2_0 0
# ThreadPoolExecutor-2_0 1
# ThreadPoolExecutor-2_0 2
# ThreadPoolExecutor-2_0 3
# ThreadPoolExecutor-2_0 4
# ThreadPoolExecutor-2_0 5
# ThreadPoolExecutor-2_0 6
# ThreadPoolExecutor-2_0 7
# ThreadPoolExecutor-2_0 8
# ThreadPoolExecutor-2_0 9
# ThreadPoolExecutor-2_0 10
# ThreadPoolExecutor-2_0 11
# ThreadPoolExecutor-2_0 12
# ThreadPoolExecutor-2_0 13
# ThreadPoolExecutor-2_0 14
# ThreadPoolExecutor-2_0 15
# ThreadPoolExecutor-2_0 16
# ThreadPoolExecutor-2_0 17
# ThreadPoolExecutor-2_0 18
# ThreadPoolExecutor-2_0 19
# ThreadPoolExecutor-2_0 20
# ThreadPoolExecutor-2_0 21
# ThreadPoolExecutor-2_0 22
# ThreadPoolExecutor-2_0 23
# ThreadPoolExecutor-2_0 24
# ThreadPoolExecutor-2_0 25
# ThreadPoolExecutor-2_0 26
# ThreadPoolExecutor-2_0 27
# ThreadPoolExecutor-2_0 28
# ThreadPoolExecutor-2_0 29
# ThreadPoolExecutor-2_0 30
# ThreadPoolExecutor-2_0 31
# ThreadPoolExecutor-2_0 32
# ThreadPoolExecutor-2_0 33
# ThreadPoolExecutor-2_0 34
# ThreadPoolExecutor-2_0 35
# ThreadPoolExecutor-2_0 36
# ThreadPoolExecutor-2_0 37
# ThreadPoolExecutor-2_0 38
# ThreadPoolExecutor-2_0 39
# ThreadPoolExecutor-2_0 40
# ThreadPoolExecutor-2_0 41
# ThreadPoolExecutor-2_0 42
# ThreadPoolExecutor-2_0 43
# ThreadPoolExecutor-2_0 44
# ThreadPoolExecutor-2_0 45
# ThreadPoolExecutor-2_0 46
# ThreadPoolExecutor-2_0 47
# ThreadPoolExecutor-2_0 48
# ThreadPoolExecutor-2_0 49
# ThreadPoolExecutor-2_0 50
# ThreadPoolExecutor-2_0 51
# ThreadPoolExecutor-2_0 52
# ThreadPoolExecutor-2_0 53
# ThreadPoolExecutor-2_0 54
# ThreadPoolExecutor-2_0 55
# ThreadPoolExecutor-2_0 56
# ThreadPoolExecutor-2_0 57
# ThreadPoolExecutor-2_0 58
# ThreadPoolExecutor-2_0 59
# ThreadPoolExecutor-2_0 60
# ThreadPoolExecutor-2_0 61
# ThreadPoolExecutor-2_0 62
# ThreadPoolExecutor-2_0 63
# ThreadPoolExecutor-2_0 64
# ThreadPoolExecutor-2_0 65
# ThreadPoolExecutor-2_0 66
# ThreadPoolExecutor-2_0 67
# ThreadPoolExecutor-2_0 68
# ThreadPoolExecutor-2_0 69
# ThreadPoolExecutor-2_0 70
# ThreadPoolExecutor-2_0 71
# ThreadPoolExecutor-2_0 72
# ThreadPoolExecutor-2_0 73
# ThreadPoolExecutor-2_0 74
# ThreadPoolExecutor-2_0 75
# ThreadPoolExecutor-2_0 76
# ThreadPoolExecutor-2_0 77
# ThreadPoolExecutor-2_0 78
# ThreadPoolExecutor-2_0 79
# ThreadPoolExecutor-2_0 80
# ThreadPoolExecutor-2_0 81
# ThreadPoolExecutor-2_0 82
# ThreadPoolExecutor-2_0 83
# ThreadPoolExecutor-2_0 84
# ThreadPoolExecutor-2_0 85
# ThreadPoolExecutor-2_0 86
# ThreadPoolExecutor-2_0 87
# ThreadPoolExecutor-2_0 88
# ThreadPoolExecutor-2_0 89
# ThreadPoolExecutor-2_0 90
# ThreadPoolExecutor-2_0 91
# ThreadPoolExecutor-2_0 92
# ThreadPoolExecutor-2_0 93
# ThreadPoolExecutor-2_0 94
# ThreadPoolExecutor-2_0 95
# ThreadPoolExecutor-2_0 96
# ThreadPoolExecutor-2_0 97
# ThreadPoolExecutor-2_0 98
# ThreadPoolExecutor-2_0 99
# True
# 1225
# 4950

# %% [markdown]
# ##### 获取执行结果

# %%
from concurrent.futures import ThreadPoolExecutor
import threading
import time


# 定义一个准备作为线程任务的函数
def action(max):
    t_sum = 0
    for i in range(max):
        print(threading.current_thread().name + ' ' + str(i))
        t_sum += i
    return t_sum


# 创建一个包含 2 条线程的线程池
with ThreadPoolExecutor(max_workers=2) as pool:
    # 向线程池提交一个 task、action 的参数为 50
    future_1 = pool.submit(action, 50)
    # 向线程池再提交一个 task、action 的参数为 100
    future_2 = pool.submit(action, 100)
    
    def get_result(future):
        print(future.result())

    # 为 future_1 添加线程完成的回调函数
    future_1.add_done_callback(get_result)
    # 为 future_2 添加线程完成的回调函数
    future_2.add_done_callback(get_result)
    print('-----------------------------')
# Out:
# ThreadPoolExecutor-3_0 0
# ThreadPoolExecutor-3_0 1
# ThreadPoolExecutor-3_0 2
# ThreadPoolExecutor-3_0 3
# ThreadPoolExecutor-3_0 4
# ThreadPoolExecutor-3_0 5
# ThreadPoolExecutor-3_0 6
# ThreadPoolExecutor-3_0 7
# ThreadPoolExecutor-3_0 8
# ThreadPoolExecutor-3_0 9
# ThreadPoolExecutor-3_0 10
# ThreadPoolExecutor-3_0 11
# ThreadPoolExecutor-3_0 12
# ThreadPoolExecutor-3_0 13
# ThreadPoolExecutor-3_0 14
# ThreadPoolExecutor-3_0 15
# ThreadPoolExecutor-3_0 16
# ThreadPoolExecutor-3_0 17
# ThreadPoolExecutor-3_0 18
# ThreadPoolExecutor-3_0 19
# ThreadPoolExecutor-3_0 20
# ThreadPoolExecutor-3_0 21
# ThreadPoolExecutor-3_0 22
# ThreadPoolExecutor-3_0 23
# ThreadPoolExecutor-3_0 24
# ThreadPoolExecutor-3_0 25
# ThreadPoolExecutor-3_0 26
# ThreadPoolExecutor-3_0 27
# ThreadPoolExecutor-3_0 28
# ThreadPoolExecutor-3_0 29
# ThreadPoolExecutor-3_0 30
# ThreadPoolExecutor-3_0 31
# ThreadPoolExecutor-3_0 32
# ThreadPoolExecutor-3_0 33
# ThreadPoolExecutor-3_0 34
# ThreadPoolExecutor-3_0 35
# ThreadPoolExecutor-3_0 36
# ThreadPoolExecutor-3_0 37
# ThreadPoolExecutor-3_0 38
# ThreadPoolExecutor-3_0 39
# ThreadPoolExecutor-3_0 40
# ThreadPoolExecutor-3_0 41
# ThreadPoolExecutor-3_0 42
# ThreadPoolExecutor-3_0 43
# ThreadPoolExecutor-3_0 44
# ThreadPoolExecutor-3_0 45
# ThreadPoolExecutor-3_0 46
# ThreadPoolExecutor-3_0 47
# ThreadPoolExecutor-3_0 48
# ThreadPoolExecutor-3_0 49
# 1225
# -----------------------------
# ThreadPoolExecutor-3_0 0
# ThreadPoolExecutor-3_0 1
# ThreadPoolExecutor-3_0 2
# ThreadPoolExecutor-3_0 3
# ThreadPoolExecutor-3_0 4
# ThreadPoolExecutor-3_0 5
# ThreadPoolExecutor-3_0 6
# ThreadPoolExecutor-3_0 7
# ThreadPoolExecutor-3_0 8
# ThreadPoolExecutor-3_0 9
# ThreadPoolExecutor-3_0 10
# ThreadPoolExecutor-3_0 11
# ThreadPoolExecutor-3_0 12
# ThreadPoolExecutor-3_0 13
# ThreadPoolExecutor-3_0 14
# ThreadPoolExecutor-3_0 15
# ThreadPoolExecutor-3_0 16
# ThreadPoolExecutor-3_0 17
# ThreadPoolExecutor-3_0 18
# ThreadPoolExecutor-3_0 19
# ThreadPoolExecutor-3_0 20
# ThreadPoolExecutor-3_0 21
# ThreadPoolExecutor-3_0 22
# ThreadPoolExecutor-3_0 23
# ThreadPoolExecutor-3_0 24
# ThreadPoolExecutor-3_0 25
# ThreadPoolExecutor-3_0 26
# ThreadPoolExecutor-3_0 27
# ThreadPoolExecutor-3_0 28
# ThreadPoolExecutor-3_0 29
# ThreadPoolExecutor-3_0 30
# ThreadPoolExecutor-3_0 31
# ThreadPoolExecutor-3_0 32
# ThreadPoolExecutor-3_0 33
# ThreadPoolExecutor-3_0 34
# ThreadPoolExecutor-3_0 35
# ThreadPoolExecutor-3_0 36
# ThreadPoolExecutor-3_0 37
# ThreadPoolExecutor-3_0 38
# ThreadPoolExecutor-3_0 39
# ThreadPoolExecutor-3_0 40
# ThreadPoolExecutor-3_0 41
# ThreadPoolExecutor-3_0 42
# ThreadPoolExecutor-3_0 43
# ThreadPoolExecutor-3_0 44
# ThreadPoolExecutor-3_0 45
# ThreadPoolExecutor-3_0 46
# ThreadPoolExecutor-3_0 47
# ThreadPoolExecutor-3_0 48
# ThreadPoolExecutor-3_0 49
# ThreadPoolExecutor-3_0 50
# ThreadPoolExecutor-3_0 51
# ThreadPoolExecutor-3_0 52
# ThreadPoolExecutor-3_0 53
# ThreadPoolExecutor-3_0 54
# ThreadPoolExecutor-3_0 55
# ThreadPoolExecutor-3_0 56
# ThreadPoolExecutor-3_0 57
# ThreadPoolExecutor-3_0 58
# ThreadPoolExecutor-3_0 59
# ThreadPoolExecutor-3_0 60
# ThreadPoolExecutor-3_0 61
# ThreadPoolExecutor-3_0 62
# ThreadPoolExecutor-3_0 63
# ThreadPoolExecutor-3_0 64
# ThreadPoolExecutor-3_0 65
# ThreadPoolExecutor-3_0 66
# ThreadPoolExecutor-3_0 67
# ThreadPoolExecutor-3_0 68
# ThreadPoolExecutor-3_0 69
# ThreadPoolExecutor-3_0 70
# ThreadPoolExecutor-3_0 71
# ThreadPoolExecutor-3_0 72
# ThreadPoolExecutor-3_0 73
# ThreadPoolExecutor-3_0 74
# ThreadPoolExecutor-3_0 75
# ThreadPoolExecutor-3_0 76
# ThreadPoolExecutor-3_0 77
# ThreadPoolExecutor-3_0 78
# ThreadPoolExecutor-3_0 79
# ThreadPoolExecutor-3_0 80
# ThreadPoolExecutor-3_0 81
# ThreadPoolExecutor-3_0 82
# ThreadPoolExecutor-3_0 83
# ThreadPoolExecutor-3_0 84
# ThreadPoolExecutor-3_0 85
# ThreadPoolExecutor-3_0 86
# ThreadPoolExecutor-3_0 87
# ThreadPoolExecutor-3_0 88
# ThreadPoolExecutor-3_0 89
# ThreadPoolExecutor-3_0 90
# ThreadPoolExecutor-3_0 91
# ThreadPoolExecutor-3_0 92
# ThreadPoolExecutor-3_0 93
# ThreadPoolExecutor-3_0 94
# ThreadPoolExecutor-3_0 95
# ThreadPoolExecutor-3_0 96
# ThreadPoolExecutor-3_0 97
# ThreadPoolExecutor-3_0 98
# ThreadPoolExecutor-3_0 99
# 4950
